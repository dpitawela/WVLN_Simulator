# %%
from selenium.webdriver.common.by import By
from SimulatorCommunicator import setup, switchToIframe, scrollToTheBottom, updateURL, clickElement, takeScreenshot
from PIL import Image

import networkx as nx
import random
import matplotlib.pyplot as plt
import re
import json
import base64
import time
import requests
import io
import itertools
import pandas as pd
import os

# %%
def getAllClickables(driver):
    elements = []

    elements_a = driver.find_elements(By.TAG_NAME, 'a')
    for element in elements_a:
        if element.is_displayed() and element.is_enabled() and element.rect.__len__() != 0:  # excluding all the hidden links
            # print(element.get_property('attributes')[0].items(), "\n")

            data = {}
            data['x'] = element.rect['x']
            data['y'] = element.rect['y']
            data['width'] = element.rect['width']
            data['height'] = element.rect['height']
            data['outer_html'] = base64Encode(bytes(element.get_attribute('outerHTML'), "utf-8")) 
            data['href'] = element.get_dom_attribute('href')
            data['href_full'] = element.get_attribute('href')
            data['class'] = element.get_attribute('class')

            texts = list(itertools.chain(*[text.text.split('\n') for text in element.find_elements(By.XPATH, '..//div')]))
            texts.append(element.text)
            data['text'] = list(set([text for text in texts if len(text) > 0] ))

            # getting closer image(s) if available
            imgs=element.find_elements(By.XPATH, ".//img")
            if len(imgs) > 0:
                for i, img in enumerate(imgs):
                    data['img_'+str(i)] = imgURL2B64(img.get_attribute('src'))

            elements.append(data)
    return elements

# to get the URL of current page on iframe
def getCurrntURLIFrame(driver):
    url = driver.execute_script('return location.href')
    url = url.replace('http://localhost:4200', "")
    return url

# download image from URL and convert to base64
def imgURL2B64(imgURL):
    # downloading image
    img_data = requests.get(imgURL).content
    # encoding
    return base64Encode(img_data)

# convert bytes string to b64 
def base64Encode(data):
    return base64.b64encode(data).decode("utf-8")

# show image from base64
def imgFromB64(imgb64):
    # reconstructing the image by decoding
    img64dec = base64.b64decode(imgb64)
    Image.open(io.BytesIO(img64dec)).show()

# format data to store
def formatData(chosenLink):
    data = {}
    data['y'] = chosenLink['y']
    data['y_offset'] = 0
    data['x'] = chosenLink['x']
    data['x_offset'] = 0
    
    if chosenLink['y'] + chosenLink['height'] > 865:
        data['y_offset'] = chosenLink['y'] + chosenLink['height'] - 865
        data['y'] = chosenLink['y'] - data['y_offset']

    if chosenLink['x'] + chosenLink['width'] > 812:
        data['x_offset'] = chosenLink['x'] + chosenLink['width'] - 812
        data['x'] = chosenLink['x'] - data['x_offset']

    # new attributes to the chosen link
    chosenLink['type'] = "click"
    chosenLink['y'] = data['y']
    chosenLink['y_offset'] = data['y_offset']
    chosenLink['x'] = data['x']
    chosenLink['x_offset'] = data['x_offset']
    return chosenLink

# retrieves all the text on the page
def getTextOnPage(driver):
    divs = driver.find_elements(By.TAG_NAME, 'div')
    return list(set(list(itertools.chain(*[[divText for divText in divs[i].text.split('\n') if len(divText) > 0] for i in range(len(divs))]))))

def formatDataForPlayer(inputJson):
    data = {}
    data['url'] = inputJson['url']

    actions = [];
    for in_action in inputJson['actions'][:-1]:
        action = {}
        action['type'] = in_action['clicked']['type']
        action['x'] = in_action['clicked']['x']
        action['y'] = in_action['clicked']['y']
        action['height'] = in_action['clicked']['height']
        action['width'] = in_action['clicked']['width']
        action['x_offset'] = in_action['clicked']['x_offset']
        action['y_offset'] = in_action['clicked']['y_offset']
        action['href'] = in_action['clicked']['href']
        action['href_full'] = in_action['clicked']['href_full']
        action['outer_html'] = in_action['clicked']['outer_html']

        actions.append(action)
        
    data['actions'] = actions
    return data

# %%
# checks one against a list
def isSimilar(query, reference, score):
    points = 0
    # relative url match
    if(query[0]) == reference[0]:
        points += 1

    # absolute url match
    if(query[1]) == reference[1]:
        points += 1
  
    # class match  
    if(query[2]) == reference[2]:
        points += 1 

    return points >= score

# check one url
def checkIfIn(query, urlList, score=2):
    for url in urlList:
        if isSimilar(query, url, score):
            return True
    
    return False

# %%
l1 = [
     ('collections/placemats.html', 'collections/placemats.html', ''),
     ('collections/notepads.html', 'collections/notepads.html', ''),
     ('collections/note-cards.html', 'collections/note-cards.html', ''),
     # ('collections/gift-labels.html', 'collections/gift-labels.html', ''),
     # ('collections/name-labels.html', 'collections/name-labels.html', ''),
     # ('collections/return-address-labels.html', 'collections/return-address-labels.html', ''),
     # ('collections/throw-pillows.html', 'collections/throw-pillows.html', ''),
     # ('collections/blankets.html', 'collections/blankets.html', ''),
     # ('collections/tote-bags.html', 'collections/tote-bags.html', ''),
     # ('collections/ceramic-mugs.html', 'collections/ceramic-mugs.html', ''),
     # ('collections/camp-mugs.html', 'collections/camp-mugs.html', ''),
     # ('collections/pillowcases.html', 'collections/pillowcases.html', ''),
     # ('collections/puzzles.html', 'collections/puzzles.html', ''),
     # ('collections/chore-charts.html', 'collections/chore-charts.html', ''),
     # ('collections/teacher-gifts.html', 'collections/teacher-gifts.html', ''),
]

l2 = [

]

l3 = [

]

eliminate = [
     ('account/login.html', 'account/login.html', ''),
     ('account/register.html', 'account/register.html', ''),
     ('cart.html', 'cart.html', ''),
     ('index.html', 'index.html', ''),
     ('https://www.facebook.com/sarahandabraham', 'https://www.facebook.com/sarahandabraham', 'facebook'),
     ('https://twitter.com/sarahandabraham', 'https://twitter.com/sarahandabraham', 'twitter'),
     ('http://www.pinterest.com/sarahandabraham/', 'http://www.pinterest.com/sarahandabraham/', 'pinterest'),
     ('https://www.instagram.com/sarahandabraham/', 'https://www.instagram.com/sarahandabraham/', 'instagram'),
     ('pages/about-us.html', 'pages/about-us.html', ''),
     ('pages/faq.html', 'pages/faq.html', ''),
     ('pages/contact.html', 'pages/contact.html', ''),
     ('http://sarahandabraham.com/blog/', 'http://sarahandabraham.com/blog/', ''),
     ('collections/all.html', 'collections/all.html', ''),
     ('http://www.aeolidia.com/', 'http://www.aeolidia.com/', ''),
     ('', '', 'bx-prev'),
     ('', '', 'bx-next')
]

pageBottomURLs = [
     
]

forceClick = [

]

def l3Handle(l2):
     if ("womens" in l2['href']):
          return l3[:7]
     elif("kids" in l2['href']):
          return l3[7:12]
     elif("mens" in l2['href']):
          return l3[12:]

# %%
# # removing stepitr/code used to generate lot of data start from middle button
# base = "http://localhost:4200/assets/crawled/sna/www.sarahandabraham.com/index.html"

# def collectData():
#     stepitr = 3
#     dpoint=1
#     no_products = 0 # flag to identify if all the products are visited
#     selected_products = []
#     while dpoint <= 500: # no. of recordings needed from one seq. count
#         driver = setup(9222, True)
#         switchToIframe(driver)

#         menuState = 'non'
#         visited = [] # to store visited links in one sequence
#         data = {} # to collect data in one sequence
#         data['url'] = "assets/crawled/sna/www.sarahandabraham.com/index.html"
#         actions = [] # to store clicks

#         try:
#             # steps = random.choice([x for x  in range(3,8)]) # generating number of steps
#             step=0
#             while step <= stepitr: # going through steps in a single data point, adding one more to include the details of the last page
#             # for step in range(stepitr + 1):
#                 scrollToTheBottom(driver)

#                 candidate_clickables = getAllClickables(driver)
#                 forRecords = candidate_clickables.copy()

#                 # remove everytime
#                 candidate_clickables = [clickable for clickable in candidate_clickables if not checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), pageBottomURLs, 2)]
                
#                 # eliminating already visited ones
#                 candidate_clickables = [clickable for clickable in candidate_clickables if not checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), visited, 2)]

#                 # keep only varients if at least 2 more steps aren't available
#                 if step != 0 and any(x in actions[-1]['clicked']['href'] for x in ['products', 'variant']) and step + 2 >= stepitr:
#                     candidate_clickables = [clickable for clickable in candidate_clickables if '?variant' in clickable['href']]
#                     step = step-1 if len(candidate_clickables) >= 2 else step
#                     step = stepitr if len(actions) == 6 and len(candidate_clickables) > 0 else step
                
#                 if step==1 and actions[-1]['clicked']['href'] in "/index.html": # to click on a product in the 1st step
#                     candidate_clickables = [clickable for clickable in candidate_clickables if '/products' in clickable['href']]

#                 # adding constraints to click a button
#                 if dpoint <= 1000 and step == 0:
#                     clickables = [clickable for clickable in candidate_clickables if checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), forceClick, 3)]
#                 else:
#                     if menuState == 'non':
#                     # eliminating unwanted urls
#                         clickables = [clickable for clickable in candidate_clickables if not checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), eliminate, 2)]
#                     elif menuState == 'l1':
#                         clickables = [clickable for clickable in candidate_clickables if checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), l2)]
#                     elif menuState == 'l2':
#                         clickables = [clickable for clickable in candidate_clickables if checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), l3Handle(actions[-1]['clicked']))]

#                 # choosing a clickable randomly
#                 if step < stepitr:
#                     # removing already visited products
#                     if step==1 and actions[-1]['clicked']['href'] in "/index.html" and len(selected_products)>0:
#                         clickables = [clickable for clickable in clickables if clickable['href_full'] not in selected_products]
#                         no_products = no_products+1 if len(clickables)==0 else 0 # to identify if all the products were visited

#                     random.seed()
#                     random.shuffle(clickables)
#                     random.shuffle(clickables)
#                     chosenLink = random.choice(clickables)

#                     if step==1 and '/products' in chosenLink['href']:
#                         selected_products.append(chosenLink['href_full'])
                    
#                     # assigning the menu state
#                     if checkIfIn((chosenLink['href'], chosenLink['href_full'].replace(base,""), chosenLink['class']), l1):
#                         menuState = 'l1'
#                     elif checkIfIn((chosenLink['href'], chosenLink['href_full'].replace(base,""), chosenLink['class']), l2[1:]):
#                         menuState = 'l2'
#                     else:
#                         menuState = 'non'
                    
#                     # adding to the visited list
#                     visited.append((chosenLink['href'], chosenLink['href_full'].replace(base,""), chosenLink['class']))

#                 actions.append({
#                     'clicked': formatData(chosenLink.copy()) if step < stepitr else None,
#                     'candidates': [formatData(clickable.copy()) for clickable in forRecords],
#                     'screenshot': takeScreenshot(driver),
#                     'full_url': getCurrntURLIFrame(driver),
#                     'text': getTextOnPage(driver)
#                     })

#                 # print(chosenLink['href_full'])
#                 if step < stepitr:
#                     clickElement(driver, chosenLink['x'], chosenLink['y'])
#                 step += 1

#             data['actions'] = actions
#             data['nClicks'] = len(actions)-1

#             # saving to a json file for ML
#             fname = 'R_' + str(int(time.time())) + '_' + str(len(actions)-1)
#             with open('data/' + fname + '.json', 'w') as f:
#                 json.dump(data, f)

#             # saving to a json file for player
#             with open('data_player/' + fname + '.json', 'w') as f:
#                 json.dump(formatDataForPlayer(data), f)
            
#             dpoint+=1 # increasing the iteration number
#             print(fname, [action['clicked']['href'] for action in actions[:-1]])

#             # break
#         except Exception as e:
#             print("error", e)
#             if no_products == 3:
#                 selected_products.clear()
#         #     # print('\033[91m', 'step_itr:', stepitr, 'dpoint:', dpoint)
#         #     # print(chosenLink['href_full'], '\n')
#         #     # if actions.__len__() > 0:
#         #     #     print([action['href'] for action in actions])
#         #     # print('\033[0m', "-----------------------------------------------------")
# collectData()

# %%
# start from menu
base = "http://localhost:4200/assets/crawled/sna/www.sarahandabraham.com/"

def collectData():
    stepitr = 2
    dpoint=1
    no_products = 0 # flag to identify if all the products are visited
    selected_products = []
    while dpoint <= 500: # no. of recordings needed from one seq. count
        driver = setup(9222, 'assets/crawled/sna/www.sarahandabraham.com/index.html', True)
        switchToIframe(driver)

        menuState = 'non'
        visited = [] # to store visited links in one sequence
        data = {} # to collect data in one sequence
        data['url'] = "assets/crawled/sna/www.sarahandabraham.com/index.html"
        actions = [] # to store clicks

        try:
            step=0
            while step <= stepitr: # going through steps in a single data point, adding one more to include the details of the last page

                scrollToTheBottom(driver)
                candidate_clickables = getAllClickables(driver)
                forRecords = candidate_clickables.copy()

                # remove everytime
                candidate_clickables = [clickable for clickable in candidate_clickables if not checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), eliminate, 2)]

                # eliminating already visited ones
                candidate_clickables = [clickable for clickable in candidate_clickables if not checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), visited, 2)]

                # keep only varients if at least 2 more steps aren't available
                if step != 0 and len(actions)>=2 and any(x in actions[-1]['clicked']['href_full'] for x in ['products']) and step + 1 >= stepitr:
                    candidate_clickables = [clickable for clickable in candidate_clickables if 'products' in clickable['href_full']]
                    step = step-1 if len(candidate_clickables) >= 1 else step
                    step = stepitr if len(actions) == 6 and len(candidate_clickables) > 0 else step 

                # adding constraints to click a button
                if step == 0:
                    candidate_clickables = [clickable for clickable in candidate_clickables if clickable['x'] < 116]
                    candidate_clickables = [clickable for clickable in candidate_clickables if checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), l1, 2)]
                elif len(actions) >= 1:
                    candidate_clickables = [clickable for clickable in candidate_clickables if 'products' in clickable['href_full']]


                # choosing a clickable randomly
                if step < stepitr:
                    # removing already visited products
                    if step==1 and len(actions) == 1 and len(selected_products)>0:
                        candidate_clickables = [clickable for clickable in candidate_clickables if clickable['href_full'] not in selected_products]
                        no_products = no_products+1 if len(candidate_clickables)==0 else no_products # to identify if all the products were visited

                    random.seed()
                    random.shuffle(candidate_clickables)
                    chosenLink = random.choice(candidate_clickables)

                    if step == 1 and '/products' in chosenLink['href_full']:
                        selected_products.append(chosenLink['href_full'])
                    
                    # assigning the menu state
                    if checkIfIn((chosenLink['href'], chosenLink['href_full'].replace(base,""), chosenLink['class']), l1):
                        menuState = 'l1'
                    else:
                        menuState = 'non'
                    
                    # adding to the visited list
                    visited.append((chosenLink['href'], chosenLink['href_full'].replace(base,""), chosenLink['class']))

                actions.append({
                    'clicked': formatData(chosenLink.copy()) if step < stepitr else None,
                    'candidates': [formatData(clickable.copy()) for clickable in forRecords],
                    'screenshot': takeScreenshot(driver),
                    'full_url': getCurrntURLIFrame(driver),
                    'text': getTextOnPage(driver)
                    })

                # print(chosenLink['href_full'])
                if step < stepitr:
                    clickElement(driver, chosenLink['x'], chosenLink['y'])
                step += 1

            data['actions'] = actions
            data['nClicks'] = len(actions)-1

            # saving to a json file for ML
            fname = 'R_' + str(int(time.time())) + '_SA_' + str(len(actions)-1)
            with open('data/' + fname + '.json', 'w') as f:
                json.dump(data, f)

            # saving to a json file for player
            with open('data_player/' + fname + '.json', 'w') as f:
                json.dump(formatDataForPlayer(data), f)
            
            dpoint+=1 # increasing the iteration number
            print(fname, [action['clicked']['href'] for action in actions[:-1]])
            
            # break
        except Exception as e:
            print("error", e)
            if no_products >= 3:
                selected_products = []
                no_products = 0
collectData()
# Out:
# R_1674843575_SA_2 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html']
# R_1674843612_SA_3 ['collections/placemats.html', 'placemats/products/olliegraphic-placemat-superhero-girl.html', '#']
# R_1674843658_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#1', '#3', '#2']
# R_1674843699_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-t-rex.html', '#1', '#2']
# R_1674843724_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html']
# R_1674843761_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-horse-and-cow.html', '#1', '#2']
# R_1674843785_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# R_1674843807_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674843841_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#2', '#1']
# R_1674843877_SA_4 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674843900_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674843949_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#4', '#3', '#2', '#1']
# R_1674843997_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#1', '#5', '#3', '#2']
# R_1674844043_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#2', '#3', '#4', '#1']
# R_1674844082_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#2', '#1', '#3']
# R_1674844127_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#1', '#4', '#2', '#3']
# R_1674844160_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#1', '#2']
# R_1674844193_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#1', '#2']
# R_1674844230_SA_4 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-blue.html', '#1', '#2']
# R_1674844252_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674844284_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674844327_SA_5 ['collections/notepads.html', 'notepads/products/personalized-pink-chevron-notepad.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#2', '#1']
# R_1674844357_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', '#1']
# R_1674844387_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674844408_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html']
# R_1674844438_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674844483_SA_5 ['collections/placemats.html', 'placemats/products/the-great-outdoors-placemat-boy.html', '#1', '#49', '#2']
# R_1674844531_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-llama.html', '#4', '#3', '#2', '#1']
# R_1674844554_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674844596_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', '#1', '#2', '#3']
# R_1674844625_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', '#1']
# R_1674844675_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-place-mat-girl.html', '#77', '#78', '#76', '#1']
# R_1674844705_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepad-dots.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674844743_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-triceratops.html', '#1', '#2']
# R_1674844769_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-butterflies.html']
# R_1674844794_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-baby-dino.html']
# R_1674844827_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-princess.html', '#']
# R_1674844847_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674844870_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674844891_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674844939_SA_6 ['collections/note-cards.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#5', '#2', '#3', '#1']
# R_1674844967_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# R_1674845010_SA_5 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', '#1', '#2', '#40']
# R_1674845035_SA_2 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pink.html']
# R_1674845087_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-place-setting.html', '#1', '#3', '#4', '#2']
# R_1674845111_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674845142_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674845168_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-rainbow-unicorn.html']
# R_1674845194_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674845220_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674845257_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#2', '#1']
# R_1674845315_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-astronaut.html', '#1', '#2', '#4', '#51']
# R_1674845370_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#4', '#1', '#87', '#2']
# R_1674845392_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674845454_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-race-car.html', 'placemats/products/personalized-christmas-place-mat-girl.html', '#1', '#76', '#78']
# R_1674845477_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# error list index out of range
# error list index out of range
# error list index out of range
# R_1674845576_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#2', '#1', '#25', '#4']
# R_1674845600_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674845624_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html']
# R_1674845662_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#2', '#1']
# R_1674845703_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-whale.html', '#2', '#1']
# R_1674845760_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-astronaut.html', '#51', '#4', '#2', '#1']
# R_1674845787_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-pink.html']
# R_1674845832_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-tractor.html', '#3', '#2', '#1']
# R_1674845860_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-sea-turtle.html']
# R_1674845884_SA_2 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html']
# R_1674845938_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#1', '#3', '#87', '#2']
# R_1674845988_SA_5 ['collections/placemats.html', 'placemats/products/great-outdoors-placemat-girl.html', '#77', '#2', '#1']
# R_1674846012_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674846050_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-spinosaurus.html', 'placemats/products/personalized-kids-placemat-multi-chevron-pink.html']
# R_1674846074_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674846099_SA_2 ['collections/notepads.html', 'notepads/products/personalized-pink-chevron-notepad.html']
# R_1674846126_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-stegosaurus.html']
# R_1674846150_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674846179_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-butterflies.html']
# R_1674846204_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674846246_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-pink-unicorn.html', 'placemats/products/personalized-chevron-placemat-green.html']
# R_1674846274_SA_2 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pink.html']
# R_1674846300_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674846346_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#3', '#2', '#1']
# R_1674846370_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-rainbow-unicorn.html']
# R_1674846398_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-blue.html']
# R_1674846445_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', '#2', '#1', '#3']
# R_1674846491_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#2', '#1', '#3']
# R_1674846519_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-baby-dino.html']
# R_1674846545_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674846570_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html']
# R_1674846608_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#2', '#1']
# R_1674846633_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674846665_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674846701_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#1', '#2']
# R_1674846723_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-pink-owl-note-cards.html']
# R_1674846780_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-placemat-boy.html', '#1', '#48', '#50', '#49']
# R_1674846812_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', '#1']
# R_1674846835_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674846881_SA_5 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', '#40', '#1', '#2']
# R_1674846933_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#2', '#1', '#3', '#4']
# R_1674846986_SA_6 ['collections/note-cards.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#5', '#3', '#2', '#1']
# R_1674847015_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674847066_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-boy.html', '#3', '#2', '#1', '#4']
# R_1674847090_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674847129_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-dump-truck.html', '#2', '#1']
# R_1674847158_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-hearts.html']
# R_1674847211_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#5', '#3', '#4', '#1']
# R_1674847234_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674847258_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html']
# R_1674847301_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-t-rex.html', '#2', '#1']
# R_1674847327_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674847358_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674847382_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674847421_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#1', '#2']
# R_1674847446_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# R_1674847497_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#3', '#2', '#1', '#4']
# R_1674847521_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674847555_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', '#1']
# R_1674847587_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674847619_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# error list index out of range
# R_1674847673_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fox.html', '#2', '#1']
# error list index out of range
# R_1674847725_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#2', '#1']
# R_1674847764_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-castle.html', '#1', '#2']
# error list index out of range
# R_1674847801_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674847842_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-turtle.html', '#1', '#2']
# R_1674847875_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', 'note-cards/products/personalized-pink-owl-note-cards.html']
# R_1674847928_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#4', '#3', '#5', '#1']
# R_1674847993_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-dog.html', 'placemats/products/personalized-kids-placemat-dump-truck.html', 'placemats/products/personalized-kids-placemat-tucan.html', '#3', '#2']
# R_1674848018_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674848071_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#4', '#25', '#1', '#2']
# R_1674848094_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html']
# R_1674848132_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#1', '#2']
# R_1674848158_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674848184_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674848208_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674848249_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-stegosaurus.html', 'placemats/products/personalized-kids-placemat-spinosaurus.html']
# R_1674848273_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674848297_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674848328_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674848352_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674848404_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-boy.html', '#4', '#1', '#3', '#2']
# R_1674848432_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-baby-dino.html']
# R_1674848458_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html']
# R_1674848513_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#3', '#2', '#1']
# R_1674848540_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-sea-turtle.html']
# R_1674848575_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-princess.html', '#']
# R_1674848609_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674848666_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-place-mat-girl.html', '#77', '#76', '#78', '#1']
# R_1674848717_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-rainbow-unicorn.html', 'placemats/products/personalized-kids-placemat-bunny.html', '#2', '#1']
# R_1674848768_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-pink.html', 'placemats/products/personalized-kids-placemat-fox.html', '#1', '#2']
# R_1674848791_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html']
# R_1674848817_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-dots.html']
# R_1674848850_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674848891_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-triceratops.html', '#1', '#2']
# R_1674848930_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#1', '#2']
# R_1674848953_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674849001_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fire-truck.html', '#2', '#3', '#1']
# R_1674849042_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-pink-unicorn.html', '#1', '#2']
# R_1674849075_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# R_1674849099_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674849132_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674849168_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#1', '#2']
# R_1674849210_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-rainbow-unicorn.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674849245_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#2', '#1']
# R_1674849282_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#2', '#1']
# R_1674849305_SA_2 ['collections/notepads.html', 'notepads/products/personalized-pink-chevron-notepad.html']
# R_1674849328_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674849358_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', '#1']
# R_1674849382_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# R_1674849422_SA_4 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-blue.html', '#1', '#2']
# R_1674849476_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#4', '#1', '#3', '#2']
# R_1674849500_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674849551_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#1', '#3', '#87', '#4']
# R_1674849573_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674849616_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#3', '#1', '#2']
# R_1674849662_SA_5 ['collections/placemats.html', 'placemats/products/the-great-outdoors-placemat-boy.html', '#49', '#1', '#2']
# R_1674849684_SA_2 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html']
# error list index out of range
# R_1674849751_SA_5 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pink.html', 'placemats/products/personalized-kids-placemat-turtle.html', '#1', '#2']
# R_1674849802_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#2', '#1', '#3', '#4']
# R_1674849858_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-firefighter.html', '#1', '#3', '#2', '#51']
# R_1674849921_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', 'placemats/products/personalized-kids-placemat-pink-unicorn.html', 'placemats/products/personalized-kids-placemat-bunny.html', '#1', '#2']
# R_1674849944_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674849994_SA_4 ['collections/placemats.html', 'placemats/products/personalized-christmas-placemat-boy.html', 'placemats/products/personalized-kids-placemat-ladybug.html', 'placemats/products/personalized-kids-placemat-stegosaurus.html']
# error list index out of range
# R_1674850054_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#3', '#2', '#1']
# error list index out of range
# R_1674850094_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674850146_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#4', '#1', '#2', '#3']
# R_1674850170_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674850222_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#4', '#25', '#1', '#2']
# R_1674850261_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-whale.html', '#1', '#2']
# R_1674850301_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-pink-unicorn.html', '#1', '#2']
# R_1674850326_SA_2 ['collections/notepads.html', 'notepads/products/personalized-pink-chevron-notepad.html']
# R_1674850349_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674850371_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674850406_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#2', '#1']
# R_1674850440_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#1', '#2']
# R_1674850491_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-boy.html', '#1', '#3', '#2', '#4']
# R_1674850544_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#2', '#3', '#1', '#87']
# R_1674850597_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#3', '#4', '#87']
# R_1674850622_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-pink-owl-note-cards.html']
# R_1674850667_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#3', '#1', '#2']
# R_1674850704_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#2', '#1']
# R_1674850755_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#4', '#3', '#1', '#2']
# R_1674850787_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', '#1']
# R_1674850839_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#2', '#3', '#4', '#1']
# R_1674850880_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-horse-and-cow.html', '#1', '#2']
# R_1674850905_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674850943_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fox.html', '#2', '#1']
# R_1674850966_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html']
# R_1674850994_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-sea-turtle.html']
# R_1674851031_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#1', '#2']
# R_1674851058_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-dog.html']
# R_1674851109_SA_6 ['collections/note-cards.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#4', '#2', '#5', '#1']
# R_1674851140_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674851177_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-hot-air-balloon.html', '#1', '#2']
# R_1674851219_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#3', '#2', '#1']
# R_1674851245_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-spinosaurus.html']
# R_1674851268_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674851307_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# error list index out of range
# R_1674851360_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-turtle.html', '#1', '#2']
# R_1674851397_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#2', '#1']
# R_1674851463_SA_6 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pink.html', 'placemats/products/personalized-kids-placemat-ladybug.html', 'placemats/products/personalized-kids-placemat-mermaid.html', 'placemats/products/personalized-kids-placemat-whale.html', '#2']
# R_1674851487_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-rainbow-unicorn.html']
# R_1674851549_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-placemat-boy.html', 'placemats/products/olliegraphic-placemat-boy.html', '#57', '#56', '#2']
# R_1674851578_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# error list index out of range
# R_1674851646_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-tucan.html', '#2', '#3', '#1', '#4']
# R_1674851692_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', '#3', '#2', '#1']
# R_1674851724_SA_3 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674851763_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-dump-truck.html', '#2', '#1']
# R_1674851790_SA_2 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-green.html']
# R_1674851825_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674851857_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674851881_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-dots.html']
# R_1674851927_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-pink.html', 'placemats/products/personalized-kids-placemat-mermaid.html', '#']
# error list index out of range
# R_1674851982_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-butterflies.html', 'placemats/products/personalized-chevron-placemat-pink.html']
# R_1674852039_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-blue.html', 'placemats/products/personalized-kids-placemat-place-setting.html', '#1', '#2', '#3']
# R_1674852084_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#1', '#3', '#2']
# R_1674852131_SA_5 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pool.html', '#2', '#3', '#1']
# R_1674852180_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#25', '#1', '#3', '#2']
# R_1674852235_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-firefighter.html', '#1', '#3', '#51', '#4']
# R_1674852258_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674852281_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674852311_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674852337_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html']
# R_1674852360_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674852409_SA_5 ['collections/placemats.html', 'placemats/products/the-great-outdoors-placemat-boy.html', '#2', '#49', '#1']
# R_1674852431_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674852484_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#4', '#1', '#2', '#3']
# R_1674852507_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674852530_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674852553_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674852604_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-boy.html', '#3', '#2', '#1', '#4']
# R_1674852657_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#3', '#4', '#1']
# R_1674852680_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674852735_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-flamingo.html', '#2', '#1', '#3', '#4']
# R_1674852772_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#2', '#1']
# R_1674852793_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674852834_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-horse-and-cow.html', '#1', '#2']
# R_1674852857_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-pink-owl-note-cards.html']
# R_1674852910_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#1', '#3', '#87', '#2']
# R_1674852946_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-mermaid.html', '#']
# R_1674852969_SA_2 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html']
# R_1674853024_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#2', '#3', '#4']
# R_1674853047_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674853081_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#2', '#1']
# R_1674853103_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674853127_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674853164_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#2', '#1']
# R_1674853189_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674853222_SA_3 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674853267_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#1', '#3', '#2']
# R_1674853299_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674853331_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# R_1674853381_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#4', '#1', '#3', '#2']
# R_1674853416_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#1', '#2']
# R_1674853468_SA_6 ['collections/note-cards.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#1', '#3', '#4', '#2']
# R_1674853500_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', '#1']
# R_1674853547_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fire-truck.html', '#1', '#3', '#2']
# R_1674853599_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-llama.html', 'placemats/products/personalized-kids-placemat-castle.html', '#1', '#2']
# R_1674853650_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#5', '#2', '#4', '#3']
# R_1674853676_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-sea-turtle.html']
# R_1674853707_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674853743_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-princess.html', '#']
# R_1674853799_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-place-mat-girl.html', '#77', '#78', '#76', '#1']
# R_1674853839_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-t-rex.html', '#1', '#2']
# R_1674853863_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# error list index out of range
# error list index out of range
# R_1674853953_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-ladybug.html', 'placemats/products/personalized-kids-placemat-fire-truck.html', '#1', '#2', '#3']
# error list index out of range
# R_1674853991_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674854042_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#4', '#5', '#2', '#3']
# R_1674854074_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674854105_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', '#1']
# R_1674854138_SA_3 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674854165_SA_2 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pink.html']
# R_1674854189_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674854242_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-tucan.html', '#4', '#2', '#1', '#3']
# R_1674854282_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-triceratops.html', '#2', '#1']
# R_1674854316_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-princess.html', '#']
# R_1674854356_SA_4 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# R_1674854403_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', '#2', '#3', '#1']
# R_1674854431_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-stegosaurus.html']
# R_1674854469_SA_3 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-green.html', 'placemats/products/personalized-kids-placemat-multi-chevron-blue.html']
# R_1674854502_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', 'notepads/products/personalized-notepad-dots.html']
# R_1674854551_SA_5 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pool.html', '#1', '#2', '#3']
# R_1674854583_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', '#1']
# R_1674854640_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-whale.html', 'placemats/products/personalized-kids-placemat-tucan.html', '#1', '#4', '#3']
# R_1674854665_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674854687_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674854732_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#3', '#2', '#1']
# R_1674854756_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674854781_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674854812_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674854843_SA_3 ['collections/note-cards.html', 'note-cards/products/personalized-pink-owl-note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674854879_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#1', '#2']
# R_1674854916_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#2', '#1']
# R_1674854938_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html']
# R_1674854979_SA_4 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-blue.html', '#1', '#2']
# R_1674855019_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-turtle.html', '#2', '#1']
# R_1674855043_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674855071_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674855108_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#1', '#2']
# R_1674855162_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-place-setting.html', '#4', '#1', '#2', '#3']
# R_1674855200_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-dump-truck.html', '#1', '#2']
# R_1674855221_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674855245_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# R_1674855284_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#2', '#1']
# R_1674855308_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html']
# R_1674855356_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-tractor.html', '#2', '#3', '#1']
# R_1674855378_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674855405_SA_2 ['collections/notepads.html', 'notepads/products/personalized-pink-chevron-notepad.html']
# R_1674855440_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#1', '#2']
# R_1674855494_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#4', '#1', '#2', '#3']
# R_1674855517_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674855540_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674855569_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-cheerful-hearts.html']
# R_1674855593_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-rainbow-unicorn.html']
# R_1674855649_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-flower.html', '#2', '#4', '#3', '#1']
# error list index out of range
# error list index out of range
# R_1674855716_SA_3 ['collections/placemats.html', 'placemats/products/olliegraphic-placemat-superhero-boy.html', '#']
# R_1674855761_SA_5 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', '#40', '#1', '#2']
# error list index out of range
# R_1674855803_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# R_1674855827_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-dots.html']
# R_1674855881_SA_5 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pool.html', 'placemats/products/personalized-kids-placemat-fox.html', '#2', '#1']
# R_1674855916_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#1', '#2']
# R_1674855956_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-t-rex.html', 'placemats/products/personalized-kids-placemat-multi-chevron-pink.html']
# R_1674855984_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-stegosaurus.html']
# R_1674856014_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674856058_SA_5 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#2', '#1']
# R_1674856098_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-pink-unicorn.html', '#1', '#2']
# R_1674856122_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674856174_SA_5 ['collections/placemats.html', 'placemats/products/personalized-christmas-place-mat-girl.html', 'placemats/products/personalized-kids-placemat-hot-air-balloon.html', '#2', '#1']
# R_1674856197_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674856220_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html']
# R_1674856246_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674856270_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674856297_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-hearts.html']
# R_1674856353_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-flamingo.html', '#4', '#3', '#1', '#2']
# R_1674856392_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-turtle.html', '#1', '#2']
# R_1674856447_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-place-setting.html', '#2', '#3', '#1', '#4']
# R_1674856500_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#3', '#2', '#25', '#1']
# R_1674856524_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html']
# R_1674856577_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#1', '#5', '#3', '#2']
# R_1674856611_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674856663_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#3', '#4', '#87', '#2']
# R_1674856717_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-ladybug.html', '#2', '#4', '#1', '#3']
# R_1674856768_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#3', '#1', '#2', '#4']
# R_1674856792_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674856846_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#5', '#3', '#1']
# R_1674856880_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-princess.html', '#']
# R_1674856926_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-triceratops.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674856949_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674856988_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#2', '#1']
# R_1674857020_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', '#1']
# ...
# R_1674857463_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-sea-turtle.html']
# R_1674857491_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-blue.html']
# R_1674857515_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674857543_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-butterflies.html']
# R_1674857588_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#1', '#2', '#3']
# R_1674857623_SA_3 ['collections/placemats.html', 'placemats/products/olliegraphic-placemat-ballerina.html', '#']
# R_1674857675_SA_5 ['collections/placemats.html', 'placemats/products/personalized-christmas-placemat-boy.html', 'placemats/products/personalized-kids-placemat-bunny.html', '#2', '#1']
# R_1674857705_SA_3 ['collections/notepads.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674857756_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#3', '#4', '#1', '#2']
# R_1674857781_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674857819_SA_4 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', '#2', '#1']
# R_1674857842_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674857873_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674857900_SA_2 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pink.html']
# R_1674857923_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html']
# R_1674857969_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fire-truck.html', '#2', '#3', '#1']
# R_1674857994_SA_2 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html']
# R_1674858023_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# R_1674858046_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-pink-owl-note-cards.html']
# R_1674858096_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', 'placemats/products/personalized-kids-placemat-t-rex.html', '#1', '#2']
# R_1674858123_SA_2 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-gray.html']
# error list index out of range
# R_1674858185_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-race-car.html', '#3', '#1', '#2']
# error list index out of range
# R_1674858223_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674858251_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-baby-dino.html']
# error list index out of range
# R_1674858293_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674858349_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-place-setting.html', '#2', '#3', '#4', '#1']
# R_1674858406_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-placemat-boy.html', '#48', '#49', '#50', '#1']
# R_1674858447_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-t-rex.html', '#1', '#2']
# R_1674858493_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#1', '#2', '#3']
# R_1674858521_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-hearts.html']
# R_1674858572_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#2', '#3', '#4', '#1']
# R_1674858621_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-tractor.html', '#3', '#2', '#1']
# R_1674858644_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-race-car-note-cards.html']
# R_1674858683_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-horse-and-cow.html', '#1', '#2']
# R_1674858707_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674858731_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674858755_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-rainbow-unicorn.html']
# R_1674858778_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674858827_SA_5 ['collections/placemats.html', 'placemats/products/the-great-outdoors-placemat-boy.html', '#49', '#1', '#2']
# R_1674858850_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-blossom-dots.html']
# R_1674858874_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-red-school-uniforms-1.html']
# R_1674858912_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-hot-air-balloon.html', '#1', '#2']
# R_1674858952_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#2', '#1', '#3']
# R_1674858990_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-turtle.html', '#1', '#2']
# R_1674859036_SA_5 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby.html', '#2', '#40', '#1']
# R_1674859060_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674859110_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-flamingo.html', '#3', '#1', '#2', '#4']
# R_1674859136_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-baby-dino.html']
# R_1674859158_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674859208_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-boy.html', '#2', '#4', '#3', '#1']
# R_1674859243_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#1', '#2']
# R_1674859287_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fire-truck.html', '#2', '#1', '#3']
# R_1674859309_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674859359_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-blue.html', 'placemats/products/personalized-kids-placemat-t-rex.html', '#2', '#1']
# R_1674859407_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-owl.html', 'placemats/products/personalized-kids-placemat-dump-truck.html', '#1', '#2']
# R_1674859432_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-stegosaurus.html']
# R_1674859459_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674859489_SA_3 ['collections/notepads.html', 'notepads/products/a-note-from-mom-floral-bouquet.html', 'notepads/products/personalized-notepads-for-mom-3-kids.html']
# R_1674859517_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-girl.html', '#']
# R_1674859567_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-firefighter.html', '#51', '#2', '#3', '#4']
# R_1674859612_SA_6 ['collections/note-cards.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#2', '#3', '#5', '#1']
# R_1674859635_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674859657_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-pink-owl-note-cards.html']
# R_1674859682_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-butterflies.html']
# R_1674859732_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-girl.html', '#1', '#4', '#3', '#87']
# R_1674859778_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#1', '#3', '#2', '#25']
# R_1674859808_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674859836_SA_3 ['collections/notepads.html', 'notepads/products/personalized-notepads-elizabeth.html', '#']
# R_1674859879_SA_5 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-pool.html', '#1', '#2', '#3']
# R_1674859913_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-reading.html', '#2', '#1']
# R_1674859942_SA_3 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674859963_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-papaya-dots.html']
# R_1674860013_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-astronaut.html', '#3', '#4', '#2', '#1']
# R_1674860062_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#3', '#4', '#1', '#2']
# R_1674860111_SA_6 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-boy.html', '#5', '#3', '#4', '#1']
# R_1674860145_SA_4 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-grace.html', '#1', '#2']
# R_1674860173_SA_3 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674860209_SA_4 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html', 'notepads/products/personalized-teacher-notepads.html', '#']
# R_1674860260_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-fire-truck-note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', 'note-cards/products/flat-family-note-cards-choose-your-silhouettes-1.html', '#1', '#4']
# R_1674860283_SA_2 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-green.html']
# R_1674860305_SA_2 ['collections/notepads.html', 'notepads/products/personalized-notepad-dots.html']
# R_1674860328_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674860359_SA_3 ['collections/notepads.html', 'notepads/products/handwriting-practice-notepad-papaya.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674860382_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-pink-banner.html']
# R_1674860404_SA_2 ['collections/notepads.html', 'notepads/products/personalized-pink-chevron-notepad.html']
# error list index out of range
# R_1674860455_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-school-days.html', 'notepads/products/personalized-kids-notepads-butterfly.html', '#']
# R_1674860486_SA_3 ['collections/placemats.html', 'placemats/products/olliegraphic-placemat-ballerina.html', '#']
# R_1674860509_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674860564_SA_6 ['collections/placemats.html', 'placemats/products/personalized-christmas-place-mat-girl.html', 'placemats/products/personalized-kids-placemat-flamingo.html', '#3', '#1', '#2']
# R_1674860598_SA_4 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-kids-jumping.html', '#2', '#1']
# error list index out of range
# error list index out of range
# R_1674860674_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-ladybug.html', '#1', '#3', '#4', '#2']
# R_1674860697_SA_2 ['collections/notepads.html', 'notepads/products/personalized-blue-chevron-notepad.html']
# R_1674860720_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-banner.html']
# R_1674860742_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-rainbow-unicorn-note-cards.html']
# R_1674860782_SA_5 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-bird.html', '#3', '#2', '#1']
# R_1674860836_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-t-rex.html', 'placemats/products/personalized-kids-placemat-tractor.html', '#3', '#1', '#2']
# R_1674860866_SA_3 ['collections/note-cards.html', 'note-cards/products/custom-childrens-flat-cards-baby-boy.html', '#1']
# R_1674860891_SA_2 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-spinosaurus.html']
# R_1674860939_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-llama.html', 'placemats/products/personalized-kids-placemat-whale.html', '#2', '#1']
# R_1674860976_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-dump-truck.html', '#2', '#1']
# R_1674861013_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-fox.html', '#2', '#1']
# R_1674861058_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-girl.html', '#25', '#3', '#2', '#4']
# R_1674861079_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-blue-school-uniforms.html']
# R_1674861112_SA_4 ['collections/notepads.html', 'notepads/products/personalized-notepad-for-mom-2-kids.html', '#2', '#1']
# R_1674861151_SA_5 ['collections/note-cards.html', 'note-cards/products/3-sibling-flat-note-cards-choose-your-silhouettes-test.html', '#1', '#2', '#3']
# R_1674861192_SA_4 ['collections/placemats.html', 'placemats/products/personalized-chevron-placemat-gray.html', 'placemats/products/personalized-kids-placemat-girl.html', '#']
# R_1674861213_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-heart.html']
# R_1674861234_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-papaya-and-green.html']
# R_1674861293_SA_6 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-multi-chevron-pink.html', 'placemats/products/personalized-christmas-place-mat-girl.html', 'placemats/products/personalized-kids-placemat-pink-unicorn.html', '#1', '#2']
# R_1674861329_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-rainbow-unicorn.html', '#2', '#1']
# R_1674861350_SA_2 ['collections/notepads.html', 'notepads/products/a-note-from-mom-blue-and-green.html']
# R_1674861387_SA_4 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-triceratops.html', '#2', '#1']
# R_1674861409_SA_2 ['collections/notepads.html', 'notepads/products/personalized-green-chevron-notepad.html']
# R_1674861457_SA_6 ['collections/placemats.html', 'placemats/products/olliegraphic-placemat-boy.html', '#57', '#58', '#56', '#1']
# R_1674861476_SA_2 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-pool-dots.html']
# R_1674861498_SA_2 ['collections/notepads.html', 'notepads/products/personalized-teacher-notepad-learning-is-fun.html']
# R_1674861544_SA_5 ['collections/placemats.html', 'placemats/products/personalized-kids-placemat-baby-dino.html', 'placemats/products/personalized-kids-placemat-whale.html', '#2', '#1']
# R_1674861589_SA_6 ['collections/note-cards.html', 'note-cards/products/personalized-note-cards-elizabeth.html', '#4', '#1', '#3', '#2']
# R_1674861634_SA_6 ['collections/note-cards.html', 'note-cards/products/flat-note-cards-choose-your-silhouette-boy.html', '#4', '#1', '#3', '#2']
# R_1674861661_SA_3 ['collections/notepads.html', 'notepads/products/custom-notepads-for-mom-boy.html', '#']
# R_1674861706_SA_6 ['collections/note-cards.html', 'note-cards/products/2-sibling-flat-note-cards-choose-your-silhouettes-1.html', '#2', '#1', '#3', '#5']

# %%
driver = setup(9222, 'assets/crawled/sna/www.sarahandabraham.com/index.html', False)
switchToIframe(driver)
# elements_a = driver.find_elements(By.TAG_NAME, 'a')

# x = getAllClickables(driver)
candidate_clickables = [(click['href'], click['href_full'].replace(base,""), click['class']) for click in getAllClickables(driver)]
# candidate_clickables = [clickable for clickable in getAllClickables(driver) if not checkIfIn((clickable['href'], clickable['href_full'].replace(base,""), clickable['class']), pageBottomURLs, 2)]
# [(click['href'], click['href_full'].replace(base,""), click['class']) for click in candidate_clickables]

# data = {
#     'href':'assets/crawled/sna/www.sarahandabraham.com/index.html',
#     'href_full':'assets/crawled/sna/www.sarahandabraham.com/index.html',
#     'x': 0,
#     'y': 0}
candidate_clickables

# %% [markdown]
# # To show an image

# %%
# to load an image
def imgFromB64(imgb64):
    # reconstructing the image by decoding
    img64dec = base64.b64decode(imgb64)
    Image.open(io.BytesIO(img64dec)).show()

with open('data/R_1674857010_SA_2.json', 'r') as f:
    imgFromB64(json.load(f)['actions'][1]['screenshot'])
    # imgFromB64(json.load(f)['actions'][1]['candidates'][31]['img_0'])

# %% [markdown]
# # Unused

# %%
def collectData(n_data):
    driver = setup()
    switchToIframe(driver)

    for i in range(n_data):
        # scrollToTheBottom(driver)
        # clickables = getAllClickables(driver)
        # chosenLink = random.choice(clickables[10:])
        # print(chosenLink)

        clickElement(driver, 414, 3000)
        break

        

# collectData(5)

# %% [markdown]
# # To delete paths

# %%
feedback = pd.read_csv("Data Quality Checker.csv")
feedback.head()
# Out:
#            File  Good  Bad
# 0  1671539062_3   1.0  NaN
# 1  1671539104_3   1.0  NaN
# 2  1671539149_3   NaN  1.0
# 3  1671539201_3   1.0  NaN
# 4  1671539251_3   1.0  NaN

# %%
# deleting bad ones
feedbackBad = feedback.copy(deep=True)
feedbackBad.File = feedbackBad.File.map(lambda x: 'R_'+ x + '.json')
bad = feedbackBad.loc[feedbackBad.Bad == 1].File.tolist()

videos = 'data_player/'
mlData = 'data/'
for (dirpath, dirnames, filenames) in os.walk(mlData):
    for filename in filenames:
        if filename in bad:
            os.remove(dirpath + filename)
            # print(dirpath, filename)

# %%
# adding good ones to a csv
feedback.File = feedback.File.map(lambda x: 'R_'+ x)
good = feedback.loc[feedback.Good == 1].File.tolist()
pd.DataFrame({'token':good}).to_csv('tokens.csv', index=False)
